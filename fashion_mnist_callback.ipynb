# %% [markdown]
# <a href="https://colab.research.google.com/github/wirelessjava2002/tensorflow-certification/blob/main/fashion_mnist_callback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A simple model in TensorFlow that uses the Fashion MNIST dataset:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load the dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize the pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Define the EarlyStopping callback
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # Monitor the validation accuracy
    patience=10,             # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore weights to the best checkpoint
)

# Define the model
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/1000
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5016 - accuracy: 0.8230 - val_loss: 0.4108 - val_accuracy: 0.8565
# Epoch 2/1000
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3778 - accuracy: 0.8634 - val_loss: 0.4080 - val_accuracy: 0.8533
# Epoch 3/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3387 - accuracy: 0.8770 - val_loss: 0.3791 - val_accuracy: 0.8611
# Epoch 4/1000
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3133 - accuracy: 0.8850 - val_loss: 0.3520 - val_accuracy: 0.8740
# Epoch 5/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2942 - accuracy: 0.8922 - val_loss: 0.3469 - val_accuracy: 0.8722
# Epoch 6/1000
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2801 - accuracy: 0.8962 - val_loss: 0.3372 - val_accuracy: 0.8793
# Epoch 7/1000
# ...

# %% [markdown]
# This model uses a single hidden layer with 128 neurons and the ReLU activation function. The output layer has 10 neurons (one for each class) with the softmax activation function. The model is compiled with the Adam optimizer and sparse categorical cross-entropy loss. It is trained for 10 epochs and evaluated on the test set.
